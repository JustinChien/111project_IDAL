# %%
import LoadingDataset
import utils
import models
import config
# Out:
# GPUs Avaliable[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]:

# %%
X_train, X_test ,y_train , y_test = LoadingDataset.loading_imgs( \
                        IMG_DIR=config.IMG_DIR, IMG_SIZE=config.IMG_SIZE, data_type=config.data_type, show_detail=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 854/854 [00:00<00:00, 888.34it/s]

# %%
model = models.create_model(config.model_name, config.data_class, config.IMG_SIZE, config.show_detail)
# Out:
# MobileNet Model Created.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  Data_augmentation (Sequenti  (None, 224, 224, 3)      0
#  al)
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  flatten (Flatten)           (None, 62720)             0
#
#  Prediction_layer (Sequentia  (None, 2)                16091266
#  l)
#
# =================================================================
# Total params: 18,349,250
# Trainable params: 16,090,498
# Non-trainable params: 2,258,752
# _________________________________________________________________

# %%
history,predictions = models.run_through(model, X_train, y_train, X_test, y_test, \
                                         lr=config.learning_rate, epochs=config.epochs, BATCH_SIZE=config.batch_size)

# # If want to do it step by step use the code below
# model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate= learning_rate),loss = tf.keras.losses.binary_crossentropy, metrics=["accuracy"])
# loss0,accuracy0 = model.evaluate(x=X_test,y=y_test,batch_size=BATCH_SIZE)
# print("initial loss: {:.2f}".format(loss0))
# print("initial accuracy: {:.2f}".format(accuracy0))
# history = model.fit(x=X_train, y=y_train, epochs=epochs, validation_data=(X_test,y_test), batch_size=BATCH_SIZE, shuffle=True)
# predictions = model.predict(x=X_test)
# Out:
# 9/9 [==============================] - 5s 122ms/step - loss: 0.9934 - accuracy: 0.3774
# initial loss: 0.99
# initial accuracy: 0.38
# Epoch 1/5
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# 19/19 [==============================] - 9s 287ms/step - loss: 1.0407 - accuracy: 0.5260 - val_loss: 0.7694 - val_accuracy: 0.5603
# Epoch 2/5
# 19/19 [==============================] - 5s 246ms/step - loss: 0.9482 - accuracy: 0.5611 - val_loss: 0.7054 - val_accuracy: 0.5992
# Epoch 3/5
# 19/19 [==============================] - 5s 248ms/step - loss: 0.9139 - accuracy: 0.5896 - val_loss: 0.7136 - val_accuracy: 0.6031
# Epoch 4/5
# 19/19 [==============================] - 5s 247ms/step - loss: 0.9211 - accuracy: 0.5863 - val_loss: 0.7256 - val_accuracy: 0.6187
# Epoch 5/5
# 19/19 [==============================] - 5s 245ms/step - loss: 0.9516 - accuracy: 0.6114 - val_loss: 0.7336 - val_accuracy: 0.6342
# 9/9 [==============================] - 1s 72ms/step

# %%
models.show_performance(history, predictions, X_train, y_train, X_test, y_test, classes=config.data_class,\
                        show_detail=config.show_detail,save_in_csv=True, note="Testing if fuction working properly")
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.49      0.86      0.62        91
#    Malignant       0.87      0.51      0.64       166
#
#     accuracy                           0.63       257
#    macro avg       0.68      0.68      0.63       257
# weighted avg       0.73      0.63      0.64       257
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17116\330415302.py in <module>
#       1 models.show_performance(history, predictions, X_train, y_train, X_test, y_test, classes=config.data_class,\
# ----> 2                         show_detail=config.show_detail,save_in_csv=True, note="Testing if fuction working properly")
#
# D:\111project\github\041-111project\models.py in show_performance(history, predictions, X_train, y_train, X_test, y_test, classes, show_detail, save_in_csv, note)
#     214     if save_in_csv:
#     215         history_report = pd.read_csv(config.report_csv_path)
# --> 216         history_report.loc[len(history_report)]=(time.ctime(time.time()),
#     217                                                     model_name,
#     218                                                     BATCH_SIZE,
#
# NameError: name 'time' is not defined

# %%
# utils.show_report(-1,show_plot=True)
